# %% [markdown]
# <a href="https://colab.research.google.com/github/siddheshgarje/Sid/blob/main/SidDVProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.style.use('bmh')
df=pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')
df
# Out:
#       Numbers        Make      Model        Variant Ex-Showroom_Price  \
# 0           0        Tata  Nano Genx             Xt      Rs. 2,92,667
# 1           1        Tata  Nano Genx             Xt      Rs. 2,92,667
# 2           2        Tata  Nano Genx             Xe      Rs. 2,36,447
# 3           3        Tata  Nano Genx             Xe      Rs. 2,36,447
# 4           4        Tata  Nano Genx        Emax Xm      Rs. 2,96,661
# ...       ...         ...        ...            ...               ...
# 2534     2534       Honda       City   Vx Mt Diesel     Rs. 13,02,000
# 2535     2535       Honda       City   Zx Mt Diesel     Rs. 14,21,000
# 2536     2536       Honda       City  Zx Cvt Petrol     Rs. 14,31,000
# 2537     2537       Honda       City   V Cvt Petrol     Rs. 12,01,000
# 2538     2538  Mitsubishi    Montero         3.2 At     Rs. 68,62,560
#
#      Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.isnull().sum()
# Out:
# Numbers                     0
# Make                        0
# Model                       0
# Variant                     0
# Ex-Showroom_Price           0
#                          ...
# Minimum_Turning_Radius    753
# Multifunction_Display     178
# Sun_Visor                 118
# Third_Row_AC_Vents        730
# Ventilation_System         70
# Length: 75, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2539 entries, 0 to 2538
# Data columns (total 75 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Numbers                         2539 non-null   int64
#  1   Make                            2389 non-null   object
#  2   Model                           2539 non-null   object
#  3   Variant                         2539 non-null   object
#  4   Ex-Showroom_Price               2539 non-null   object
#  5   Displacement                    2515 non-null   object
#  6   Cylinders                       2407 non-null   float64
#  7   Valves_Per_Cylinder             2335 non-null   float64
#  8   Drivetrain                      2525 non-null   object
#  9   Cylinder_Configuration          2513 non-null   object
#  10  Emission_Norm                   2517 non-null   object
#  11  Engine_Location                 2453 non-null   object
# ...

# %%
df.shape
# Out:
# (2539, 75)

# %%
df.describe()
# Out:
#           Numbers    Cylinders  Valves_Per_Cylinder        Doors  \
# count  2539.00000  2407.000000          2335.000000  2531.000000
# mean   1269.00000     4.382219             3.977730     4.549585
# std     733.09049     1.665298             0.835902     0.748787
# min       0.00000     2.000000             1.000000     2.000000
# 25%     634.50000     4.000000             4.000000     4.000000
# 50%    1269.00000     4.000000             4.000000     5.000000
# 75%    1903.50000     4.000000             4.000000     5.000000
# max    2538.00000    16.000000            16.000000     5.000000
#
#        Seating_Capacity
# count       2527.000000
# mean           5.263554
# std            1.143066
# min            2.000000
# 25%            5.000000
# 50%            5.000000
# 75%            5.000000
# max           16.000000

# %%
df.isnull().sum()
# Out:
# Numbers                     0
# Make                      150
# Model                       0
# Variant                     0
# Ex-Showroom_Price           0
#                          ...
# Minimum_Turning_Radius    753
# Multifunction_Display     178
# Sun_Visor                 118
# Third_Row_AC_Vents        730
# Ventilation_System         70
# Length: 75, dtype: int64

# %%
df.nunique()
# Out:
# Numbers                   2539
# Make                        39
# Model                      263
# Variant                   1064
# Ex-Showroom_Price         1179
#                           ...
# Minimum_Turning_Radius      61
# Multifunction_Display        1
# Sun_Visor                    3
# Third_Row_AC_Vents           2
# Ventilation_System          15
# Length: 75, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-13-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                       Numbers  Cylinders  Valves_Per_Cylinder     Doors  \
# Numbers              1.000000   0.144933             0.059948 -0.141267
# Cylinders            0.144933   1.000000            -0.000913 -0.507318
# Valves_Per_Cylinder  0.059948  -0.000913             1.000000 -0.030029
# Doors               -0.141267  -0.507318            -0.030029  1.000000
# Seating_Capacity    -0.013467  -0.317934            -0.024975  0.520336
#
#                      Seating_Capacity
# Numbers                     -0.013467
# Cylinders                   -0.317934
# Valves_Per_Cylinder         -0.024975
# Doors                        0.520336
# Seating_Capacity             1.000000

# %%
print(df.columns)
# Out:
# Index(['Numbers', 'Make', 'Model', 'Variant', 'Ex-Showroom_Price',
#        'Displacement', 'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration', 'Emission_Norm', 'Engine_Location',
#        'Fuel_System', 'Fuel_Tank_Capacity', 'Fuel_Type', 'Height', 'Length',
#        'Width', 'Body_Type', 'Doors', 'City_Mileage', 'Highway_Mileage',
#        'ARAI_Certified_Mileage', 'ARAI_Certified_Mileage_for_CNG',
#        'Kerb_Weight', 'Gears', 'Ground_Clearance', 'Front_Brakes',
#        'Rear_Brakes', 'Front_Suspension', 'Rear_Suspension', 'Front_Track',
#        'Rear_Track', 'Front_Tyre_&_Rim', 'Rear_Tyre_&_Rim', 'Power_Steering',
#        'Power_Windows', 'Keyless_Entry', 'Power', 'Torque', 'Odometer',
#        'Speedometer', 'Tachometer', 'Tripmeter', 'Seating_Capacity',
#        'Seats_Material', 'Type', 'Wheelbase', 'Wheels_Size',
#        'Start_/_Stop_Button', '12v_Power_Outlet', 'Average_Fuel_Consumption',
# ...

# %% [markdown]
# # UNIVARIATE **ANALYSIS**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
df=pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Data Exploration
unique_makes = df['Make'].unique()
unique_models = df['Model'].unique()

# Visualization
plt.figure(figsize=(12, 7))  # Increase the figure size
sns.countplot(y="Make", data=df, order=df['Make'].value_counts().index, palette='viridis')  # Use horizontal bar plot
plt.title("Distribution of Car Makes")
plt.xlabel("Count")
plt.ylabel("Make")
plt.show()

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(11, 6))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title('Correlation Heatmap')

plt.xticks(fontsize=9)
plt.yticks(fontsize=9)

plt.show()
# Out:
# <ipython-input-11-182fb4b0a8b1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
df['Variant'].value_counts()
# Out:
# Lxi                 18
# Vxi                 18
# Coupe               16
# S                   14
# Xe Diesel           12
#                     ..
# Asta Mt              1
# Vx Cvt Diesel        1
# Sx 1.2 Crdi          1
# Magna Mt Cng         1
# K2 6Str Cng Taxi     1
# Name: Variant, Length: 1064, dtype: int64

# %%
# Count the occurrences of each unique 'Model' value
model_counts = df['Model'].value_counts()

# Filter for the top N most frequent models if you have too many
# For example, let's say you want to plot the top 20 most frequent models
top_n = 30
top_model_counts = model_counts.head(top_n)

# Create a bar plot for the top N most frequent models
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

sns.barplot(x=top_model_counts.values, y=top_model_counts.index, palette='viridis')
plt.xlabel('Count', fontsize=14)
plt.ylabel('Model', fontsize=14)
plt.title(f'Top {top_n} Most Frequent Models', fontsize=16)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
# Clean and convert the 'Gears' column to numeric (assuming it contains non-numeric data)
df['Gears'] = pd.to_numeric(df['Gears'], errors='coerce')

# Create a frequency (count) plot for the 'Gears' column
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Create a custom color palette for the bars
colors = sns.color_palette("viridis", len(df['Gears'].unique()))

# Create the count plot with custom colors
sns.countplot(data=df, x='Gears', palette=colors)

# Adding a gradient background
ax = plt.gca()
ax.set_facecolor('#f0f0f0')

# Customizing the title and labels
plt.title('Frequency Plot of Gears', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of Gears', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Adding data labels on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height() + 50),
                ha='center', va='center', fontsize=12, color='black')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adding a color bar legend
sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=min(df['Gears']), vmax=max(df['Gears'])))
sm.set_array([])  # You need to set an empty array to create the ScalarMappable
cbar = plt.colorbar(sm, pad=0.1)
cbar.set_label('Count', fontsize=12)

# Adding a decorative grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-f346e52b7524>:34: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm, pad=0.1)

# %%
# Extract unique values and their counts in the 'Emission_Norm' column
emission_norm_counts = df['Emission_Norm'].value_counts().reset_index()
emission_norm_counts.columns = ['Category', 'Count']

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(12, 6))
sns.set_style("whitegrid")  # Set the background style

# Bar plot for Emission Norm distribution
sns.barplot(data=emission_norm_counts, x='Category', y='Count', palette='viridis', ax=ax1)
ax1.set_xlabel('Emission Norm', fontsize=14)
ax1.set_ylabel('Count', fontsize=14)
ax1.set_title('Distribution of Emission Norm', fontsize=16)
ax1.tick_params(axis='x', labelrotation=45, labelsize=12)

# Create a secondary y-axis for the line plot
ax2 = ax1.twinx()

# Line plot for cumulative count
cumulative_counts = emission_norm_counts['Count'].cumsum()
sns.lineplot(x=emission_norm_counts.index, y=cumulative_counts, marker='o', color='blue', ax=ax2)
ax2.set_ylabel('Cumulative Count', fontsize=14)

# Adjust the x-axis labels to match the categories
ax2.set_xticks(range(len(emission_norm_counts)))
ax2.set_xticklabels(emission_norm_counts['Category'], rotation=45, fontsize=12)

# Add a legend for clarity
ax1.legend(['Count'], loc='upper left')
ax2.legend(['Cumulative Count'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your CSV data into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Extract unique values and their counts in the 'Cylinder_Configuration' column
cylinder_config_counts = df['Cylinder_Configuration'].value_counts().reset_index()
cylinder_config_counts.columns = ['Category', 'Count']

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(12, 6))
sns.set_style("whitegrid")  # Set the background style

# Define a custom color palette for the bars
custom_palette = ['red', 'yellow', 'blue', '#FFFF33', '#33FFFF']

# Bar plot for Cylinder Configuration distribution with custom colors
sns.barplot(data=cylinder_config_counts, x='Category', y='Count', palette=custom_palette, ax=ax1)
ax1.set_xlabel('Cylinder Configuration', fontsize=14)
ax1.set_ylabel('Count', fontsize=14)
ax1.set_title('Distribution of Cylinder Configuration', fontsize=16)
ax1.tick_params(axis='x', labelrotation=45, labelsize=12)

# Create a secondary y-axis for the line plot (Frequency)
ax2 = ax1.twinx()

# Line plot for Frequency (Count)
frequency_counts = cylinder_config_counts['Count']
sns.lineplot(x=cylinder_config_counts.index, y=frequency_counts, marker='o', color='blue', ax=ax2)
ax2.set_ylabel('Frequency (Count)', fontsize=14)

# Adjust the x-axis labels to match the categories
ax2.set_xticks(range(len(cylinder_config_counts)))
ax2.set_xticklabels(cylinder_config_counts['Category'], rotation=45, fontsize=12)

# Add a legend for clarity
ax1.legend(['Count'], loc='upper left')
ax2.legend(['Frequency'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your CSV data into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Calculate the counts for each category in the 'Engine_Location' column
engine_location_counts = df['Engine_Location'].value_counts()

# Create a count plot with customized style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Use a count plot to show the counts of each 'Engine_Location' category with custom colors
colors = sns.color_palette('viridis', len(engine_location_counts))
sns.countplot(data=df, x='Engine_Location', palette=colors, order=engine_location_counts.index)

plt.xlabel('Engine Location', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Distribution of Engine Location', fontsize=16)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Add data labels above each bar
for i, count in enumerate(engine_location_counts):
    plt.text(i, count + 5, str(count), ha='center', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your CSV data into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Create a bar plot of 'Body_Type' counts
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

sns.countplot(data=df, x='Body_Type', palette='viridis', order=df['Body_Type'].value_counts().index)
plt.title('Distribution of Body Types', fontsize=16)
plt.xlabel('Body Type', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your CSV data into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Set the number of top categories to display
top_n = 10

# Get the top N 'Body_Type' categories by count
top_body_types = df['Body_Type'].value_counts().head(top_n).index

# Create a filtered DataFrame with only the top N categories
df_top = df[df['Body_Type'].isin(top_body_types)]

# Create a figure with two y-axes: left for bar plot and right for line plot
fig, ax1 = plt.subplots(figsize=(12, 6))
sns.set_style("whitegrid")

# Bar plot on the left y-axis
sns.countplot(data=df_top, x='Body_Type', palette='Set2', order=top_body_types, ax=ax1)
ax1.set_title(f'Top {top_n} Body Types - Bar Plot', fontsize=16)
ax1.set_xlabel('Body Type', fontsize=12)
ax1.set_ylabel('Count', fontsize=12)

# Rotate x-axis labels for better readability if needed
ax1.tick_params(axis='x', rotation=45)

# Add grid lines to the bar plot
ax1.grid(axis='y', linestyle='--', alpha=0.7)

# Create a second y-axis on the right for the line plot
ax2 = ax1.twinx()

# Line plot on the right y-axis
sns.lineplot(data=df_top, x='Body_Type', y='Body_Type', estimator='mean', ci=None, ax=ax2, color='purple', linestyle='dashed')
# Replace 'Your_Numeric_Column' with the actual numeric column you want to plot

ax2.set_ylabel('Average Numeric Value', fontsize=12)

# Add grid lines to the line plot
ax2.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust the space between subplots
fig.tight_layout()

plt.show()
# Out:
# <ipython-input-20-1719f4eca1ef>:37: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df_top, x='Body_Type', y='Body_Type', estimator='mean', ci=None, ax=ax2, color='purple', linestyle='dashed')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV data into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Create a pie chart for the 'Doors' column
plt.figure(figsize=(8, 6))

# Count the occurrences of each unique value in 'Doors'
door_counts = df['Doors'].value_counts()

# Create labels for the pie chart
labels = door_counts.index

# Create values for the pie chart
sizes = door_counts.values

# Define color options for the pie chart
colors = ['red', 'yellow', 'blue', 'pink']

# Define hatch patterns for the pie chart
hatches = ['**o', '\\', '.||.', 'o.o']

# Create the pie chart with hatch patterns
plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors,
    pctdistance=1.3,  # Set the percentage label's distance from the center
)

# Add hatch patterns to the slices
for i, patch in enumerate(plt.gca().patches):
    patch.set_hatch(hatches[i])

# Set the title
plt.title('Distribution of Doors', fontsize=16)

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV data into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Create a line plot for the 'Doors' column
plt.figure(figsize=(10, 6))

# Count the occurrences of each unique value in 'Doors'
door_counts = df['Doors'].value_counts()

# Extract x-values (unique door categories)
x_values = door_counts.index

# Extract y-values (counts)
y_values = door_counts.values

# Plot the line graph
plt.plot(x_values, y_values, marker='o', linestyle='-', color='blue')

# Set the title and labels
plt.title('Distribution of Doors', fontsize=16)
plt.xlabel('Number of Doors', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Display grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Read the CSV file with your actual data
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Convert the "Ground_Clearance" column to strings
df['Ground_Clearance'] = df['Ground_Clearance'].astype(str)

# Group the data by "Ground_Clearance" categories and count the occurrences
category_counts = df['Ground_Clearance'].value_counts()

# Sort categories by frequency in descending order
sorted_categories = category_counts.index
sorted_counts = category_counts.values

# Create a histogram of the "Ground_Clearance" data
plt.figure(figsize=(12, 6))
plt.bar(sorted_categories, sorted_counts, color='skyblue')
plt.xlabel('Ground Clearance Categories')
plt.ylabel('Frequency')
plt.title('Distribution of Ground Clearance')
plt.xticks(rotation=45, fontsize=8)  # Rotate x-axis labels for better readability if needed
plt.tight_layout()
plt.show()

# %% [markdown]
# # **BIVARIATE**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))

# Subplot 1
plt.subplot(2, 2, 1)  # Two rows, two columns, subplot 1
plt.scatter(df['Cylinders'], df['Valves_Per_Cylinder'])
plt.xlabel('Cylinders')
plt.ylabel('Valves_Per_Cylinder')
plt.title('Scatter Plot: Cylinders vs Valves_Per_Cylinder')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your CSV data into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Clean and convert the 'Fuel_Tank_Capacity' column to float
df['Fuel_Tank_Capacity'] = df['Fuel_Tank_Capacity'].str.replace('litres', '').str.replace(',', '').astype(float)

# Set the figure size
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Create a line plot to visualize 'Fuel_Tank_Capacity' by 'Fuel_Type'
sns.lineplot(data=df, x='Fuel_Type', y='Fuel_Tank_Capacity', ci=None, markers=True, marker='o', hue_order=df['Fuel_Type'].unique(), palette='viridis')
plt.title('Fuel Tank Capacity by Fuel Type', fontsize=16)
plt.xlabel('Fuel Type', fontsize=12)
plt.ylabel('Fuel Tank Capacity (litres)', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-21-82d3e807e674>:16: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x='Fuel_Type', y='Fuel_Tank_Capacity', ci=None, markers=True, marker='o', hue_order=df['Fuel_Type'].unique(), palette='viridis')
# <ipython-input-21-82d3e807e674>:16: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df, x='Fuel_Type', y='Fuel_Tank_Capacity', ci=None, markers=True, marker='o', hue_order=df['Fuel_Type'].unique(), palette='viridis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load your CSV data into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Extract unique values and their counts in the 'Cylinder_Configuration' and 'Emission_Norm' columns
cylinder_config_counts = df['Cylinder_Configuration'].value_counts().reset_index()
cylinder_config_counts.columns = ['Category', 'Count']

emission_norm_counts = df['Emission_Norm'].value_counts().reset_index()
emission_norm_counts.columns = ['Category', 'Count']

# Create a scatter plot to visualize the distribution of these values
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")  # Set the background style

# Use a scatter plot to show the counts of each category for both variables
plt.scatter(cylinder_config_counts['Category'], cylinder_config_counts['Count'], label='Cylinder Configuration', color='blue')
plt.scatter(emission_norm_counts['Category'], emission_norm_counts['Count'], label='Emission Norm', color='red')

plt.xlabel('Category', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Distribution of Cylinder Configuration and Emission Norm', fontsize=16)

plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

plt.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your CSV data into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Clean and convert the 'Ex-Showroom_Price' column to float
df['Ex-Showroom_Price'] = df['Ex-Showroom_Price'].str.replace('Rs. ', '').str.replace(',', '').astype(float)

# Calculate the average Ex-Showroom Price for each car make
average_prices_by_make = df.groupby('Make')['Ex-Showroom_Price'].mean().reset_index()

# Sort the data by average Ex-Showroom Price in descending order
sorted_data = average_prices_by_make.sort_values(by='Ex-Showroom_Price', ascending=False)

# Create a bar plot to visualize the most expensive car makes
plt.figure(figsize=(12, 8))
sns.set_style("whitegrid")

sns.barplot(x='Make', y='Ex-Showroom_Price', data=sorted_data, palette='viridis')
plt.title('Average Ex-Showroom Price by Car Make', fontsize=16)
plt.xlabel('Make', fontsize=12)
plt.ylabel('Average Ex-Showroom Price', fontsize=12)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-670bbdedd481>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Ex-Showroom_Price'] = df['Ex-Showroom_Price'].str.replace('Rs. ', '').str.replace(',', '').astype(float)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your CSV data into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1')

# Create a figure with two subplots
plt.figure(figsize=(12, 8))

# Create the first subplot for Rear Brakes
plt.subplot(2, 1, 1)
sns.countplot(data=df, x='Rear_Brakes', palette='viridis')
plt.title('Count of Rear Brakes Types', fontsize=16)
plt.xlabel('Brake Type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels if needed

# Create the second subplot for Front Brakes
plt.subplot(2, 1, 2)
sns.countplot(data=df, x='Front_Brakes', palette='viridis')
plt.title('Count of Front Brakes Types', fontsize=16)
plt.xlabel('Brake Type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels if needed

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset from a CSV file with explicit data type specification
data_types = {
    "Make": str,  # Assuming Make is a string (categorical)
    "Ex-Showroom_Price": str  # Assuming Ex-Showroom_Price is initially read as a string
}

df = pd.read_csv("/content/drive/MyDrive/Data visualization/sid dv car.csv", encoding='ISO-8859-1', dtype=data_types)

# Clean and preprocess the "Ex-Showroom_Price" column
df['Ex-Showroom_Price'] = df['Ex-Showroom_Price'].str.replace('Rs. ', '').str.replace(',', '').astype(float)

# Get the top 10 unique values in the "Make" column
top_10_makes = df['Make'].value_counts().head(10).index

# Filter the DataFrame to include only the top 10 makes
df_filtered = df[df['Make'].isin(top_10_makes)]

# Create a box plot to visualize the relationship between Make and Ex-Showroom_Price
plt.figure(figsize=(10, 5))
sns.boxplot(x="Make", y="Ex-Showroom_Price", data=df_filtered)
plt.title("Bivariate Analysis: Top 10 Makes vs. Ex-Showroom Price")
plt.xlabel("Make")
plt.ylabel("Ex-Showroom Price")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-22-ddb6631f07dc>:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Ex-Showroom_Price'] = df['Ex-Showroom_Price'].str.replace('Rs. ', '').str.replace(',', '').astype(float)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a box plot to visualize the distribution of "Ex-Showroom_Price" by "Fuel_Type"
plt.figure(figsize=(12, 6))
sns.boxplot(x='Fuel_Type', y='Ex-Showroom_Price', data=df)
plt.title("Bivariate Box Plot: Fuel_Type vs. Ex-Showroom_Price")
plt.xlabel("Fuel_Type")
plt.ylabel("Ex-Showroom_Price")
plt.xticks(rotation=45)
plt.show()
